# %% [markdown]
# ## Librerias Usadas

# %%
pip install memory-profiler
# Out:
# Requirement already satisfied: memory-profiler in c:\users\juanlh.mymiratech\appdata\local\anaconda3\lib\site-packages (0.61.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: psutil in c:\users\juanlh.mymiratech\appdata\local\anaconda3\lib\site-packages (from memory-profiler) (5.9.0)

# %%
# %load_ext memory_profiler

# %%
import json
import pandas as pd
import q1_time as q1t
import q1_memory as q1m
import q2_time as q2t
import q2_memory as q2m
import q3_time as q3t
import timeit
import cProfile
import pstats
from io import StringIO
import dataset_treatment as dt

# %% [markdown]
# ## Carga del Archivo

# %% [markdown]
# En este archivo puedes escribir lo que estimes conveniente. Te recomendamos detallar tu solución y todas las suposiciones que estás considerando. Aquí puedes ejecutar las funciones que definiste en los otros archivos de la carpeta src, medir el tiempo, memoria, etc.

# %%
file_path = "farmers-protest-tweets-2021-2-4.json"

# %% [markdown]
# Cabe resaltar que el archivo json lo incluimos en el .gitignore para no subirlo a git nunca pues es bastante pesado

# %%
# Lee el archivo JSON línea por línea y carga cada línea como un objeto JSON
with open(file_path, 'r') as file:
    data = [json.loads(line) for line in file]

# Convierte los datos en un DataFrame
df = pd.DataFrame(data)

# %% [markdown]
# ## Analisis Exploratorio

# %% [markdown]
# Durante esta sección haremos un pequeño analisis exploratorio sobre el DataFrame <em> farmers-protest-tweets-2021-2-4.json </em> para conocer un poco sobre el comportamiento de los datos

# %%
# Muestra de la primera fila de DF
df.head(1)
# Out:
#                                                  url  \
# 0  https://twitter.com/ArjunSinghPanam/status/136...
#
#                         date  \
# 0  2021-02-24T09:23:35+00:00
#
#                                              content  \
# 0  The world progresses while the Indian police a...
#
#                                      renderedContent                   id  \
# 0  The world progresses while the Indian police a...  1364506249291784198
#
#                                                 user  \
# 0  {'username': 'ArjunSinghPanam', 'displayname':...
#
#                                             outlinks  \
# 0  [https://twitter.com/ravisinghka/status/136415...
#
#                  tcooutlinks  replyCount  retweetCount  ...  quoteCount  \
# 0  [https://t.co/es3kn0IQAF]           0             0  ...           0
#
#         conversationId  lang  \
# 0  1364506249291784198    en
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                             sourceUrl         sourceLabel media  \
# 0  http://twitter.com/download/iphone  Twitter for iPhone  None
#
#   retweetedTweet                                        quotedTweet  \
# 0           None  {'url': 'https://twitter.com/RaviSinghKA/statu...
#
#                                       mentionedUsers
# 0  [{'username': 'narendramodi', 'displayname': '...
#
# [1 rows x 21 columns]

# %% [markdown]
# Haremos un recorte de nuestro DataFrame dado que solo necesitamos algunos de los atributos del DF para realizar nuestro challenge:
# 1) Date, user, id
# 2) content
# 3) user, mentionedUsers

# %%
df= df.filter(items=['id','date','content','user','mentionedUsers'])
df.head()
# Out:
#                     id                       date  \
# 0  1364506249291784198  2021-02-24T09:23:35+00:00
# 1  1364506237451313155  2021-02-24T09:23:32+00:00
# 2  1364506195453767680  2021-02-24T09:23:22+00:00
# 3  1364506167226032128  2021-02-24T09:23:16+00:00
# 4  1364506144002088963  2021-02-24T09:23:10+00:00
#
#                                              content  \
# 0  The world progresses while the Indian police a...
# 1  #FarmersProtest \n#ModiIgnoringFarmersDeaths \...
# 2  ਪੈਟਰੋਲ ਦੀਆਂ ਕੀਮਤਾਂ ਨੂੰ ਮੱਦੇਨਜ਼ਰ ਰੱਖਦੇ ਹੋਏ \nਮੇ...
# 3  @ReallySwara @rohini_sgh watch full video here...
# 4  #KisanEktaMorcha #FarmersProtest #NoFarmersNoF...
#
#                                                 user  \
# 0  {'username': 'ArjunSinghPanam', 'displayname':...
# 1  {'username': 'PrdeepNain', 'displayname': 'Pra...
# 2  {'username': 'parmarmaninder', 'displayname': ...
# 3  {'username': 'anmoldhaliwal', 'displayname': '...
# 4  {'username': 'KotiaPreet', 'displayname': 'Pre...
#
#                                       mentionedUsers
# 0  [{'username': 'narendramodi', 'displayname': '...
# 1  [{'username': 'Kisanektamorcha', 'displayname'...
# 2                                               None
# 3  [{'username': 'ReallySwara', 'displayname': 'S...
# 4                                               None

# %% [markdown]
# Hacemos una validacion en la columna <em> user </em> y <em> mentionedUsers </em> para saber si en cada fila tenemos mas de un registro en estas columnas. Me explico, suponemos que un tweet solo puede ser publicado por un usuario y que en el mismo se puede mencionar a varios usuarios.

# %%
# Verificar que cada entrada sea una lista y contar los elementos
def count_objects(lst):
    if isinstance(lst, list):
        return len(lst)
    return 0  # Retornar 0 si no es una lista

# Aplicar la función y filtrar filas donde la cuenta es mayor que 2 para la columna 'user'
df['num_users'] = df['user'].apply(count_objects)
df_more_than_two = df[df['num_users'] > 2]

print("Filas con más de 2 objetos en 'user':")
print(df_more_than_two)

# Aplicar la función y filtrar filas donde la cuenta es mayor que 2 para la columna 'mentionedUsers'
df['num_mentioned'] = df['mentionedUsers'].apply(count_objects)
df_more_than_two = df[df['num_mentioned'] > 2]

print("Filas con más de 2 objetos en 'mentionedUsers':")
print(df_more_than_two['num_mentioned'])
# Out:
# Filas con más de 2 objetos en 'user':
# Empty DataFrame
# Columns: [id, date, content, user, mentionedUsers, num_users]
# Index: []
# Filas con más de 2 objetos en 'mentionedUsers':
# 29        3
# 52        4
# 56        3
# 66        3
# 86        3
#          ..
# 117305    4
# 117339    9
# 117345    5
# 117355    3
# 117375    5
# Name: num_mentioned, Length: 10692, dtype: int64

# %% [markdown]
# Habiendo comprobado el supuesto anterior aplanaremos los datos de la siguiente manera:
#
# 1) Vamos aplanar la columna user pues solo necesitaremos username y id.
# 2) Vamos aplanar el campo mentionedUsers y lo cambiaremos por un diccionario clave (id) valor (username)
# 3) Ademas vamos a convertir el campo Date a tipo de dato DateTime

# %%
# Aplanar la columna 'user' para extraer 'username' y 'id'
df_user = pd.json_normalize(df['user'])

# Seleccionar solo las columnas 'username' e 'id'
df_user = df_user[['username', 'id']]

# Renombrar la columna "id" por "username_id" para evitar conflictos con el id del tweet
df_user = df_user.rename(columns= {'id':'id_username'})

# Unir las nuevas columnas al DataFrame original
df = pd.concat([df, df_user], axis=1)

# %%
def list_to_dict(lst):
    if lst is None:
        return None
    return {str(item['id']): item['username'] for item in lst if 'id' in item and 'username' in item}

# Aplicar la función a la columna 'mentionedUsers'
df['mentionedUsers_dict'] = df['mentionedUsers'].apply(list_to_dict)

# %%
# Eliminar la columna original 'user' y 'mentionedUsers_dict' ya que no son mas necesarios
df = df.drop(columns=['user'])
df = df.drop(columns=['mentionedUsers'])
df = df.drop(columns=['num_users'])
df = df.drop(columns=['num_mentioned'])

# %%
# Convertir la columna 'date' a DateTime
df['date'] = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#                     id                       date  \
# 0  1364506249291784198  2021-02-24T09:23:35+00:00
# 1  1364506237451313155  2021-02-24T09:23:32+00:00
# 2  1364506195453767680  2021-02-24T09:23:22+00:00
# 3  1364506167226032128  2021-02-24T09:23:16+00:00
# 4  1364506144002088963  2021-02-24T09:23:10+00:00
#
#                                              content  \
# 0  The world progresses while the Indian police a...
# 1  #FarmersProtest \n#ModiIgnoringFarmersDeaths \...
# 2  ਪੈਟਰੋਲ ਦੀਆਂ ਕੀਮਤਾਂ ਨੂੰ ਮੱਦੇਨਜ਼ਰ ਰੱਖਦੇ ਹੋਏ \nਮੇ...
# 3  @ReallySwara @rohini_sgh watch full video here...
# 4  #KisanEktaMorcha #FarmersProtest #NoFarmersNoF...
#
#                                                 user  \
# 0  {'username': 'ArjunSinghPanam', 'displayname':...
# 1  {'username': 'PrdeepNain', 'displayname': 'Pra...
# 2  {'username': 'parmarmaninder', 'displayname': ...
# 3  {'username': 'anmoldhaliwal', 'displayname': '...
# 4  {'username': 'KotiaPreet', 'displayname': 'Pre...
#
#                                       mentionedUsers  \
# 0  [{'username': 'narendramodi', 'displayname': '...
# 1  [{'username': 'Kisanektamorcha', 'displayname'...
# 2                                               None
# 3  [{'username': 'ReallySwara', 'displayname': 'S...
# 4                                               None
#
#                                  mentionedUsers_dict
# 0  {'18839785': 'narendramodi', '1850705408': 'De...
# 1         {'1338536920066879488': 'Kisanektamorcha'}
# 2                                               None
# 3  {'1546101560': 'ReallySwara', '267861878': 'ro...
# 4                                               None

# %%
def resumen_columnas(df):
    print("Información del DataFrame:\n")
    print(df.info())
    print("\nConteo de Valores Nulos:\n")
    print(df.isnull().sum())

# Aplicar la función
resumen_columnas(df)
# Out:
# Información del DataFrame:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 6 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   id                   117407 non-null  int64
#  1   date                 117407 non-null  datetime64[ns, UTC]
#  2   content              117407 non-null  object
#  3   username             117407 non-null  object
#  4   id_username          117407 non-null  int64
#  5   mentionedUsers_dict  38034 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(2), object(3)
# memory usage: 5.4+ MB
# None
#
# Conteo de Valores Nulos:
#
# id                         0
# date                       0
# content                    0
# username                   0
# id_username                0
# mentionedUsers_dict    79373
# dtype: int64

# %% [markdown]
# Hemos terminado nuestro Analisis Exploratorio el cual mas que ir enfocado en detectar valores atípicos, evaluar la distribución de las variables, y visualizar las correlaciones entre ellas. Me he enfocado en entender y comprender el comportamiento de los datos y disminuir el dataset para lo necesario en el challenge

# %% [markdown]
# ## Top 10 Fechas con mas Tweets

# %% [markdown]
# ### TIEMPO

# %% [markdown]
# Las top 10 fechas donde hay más tweets. Mencionar el usuario (username) que más publicaciones tiene por cada uno de esos días.

# %%
# Medir tiempo de ejecución con py-spy
execution_time = timeit.timeit(lambda: q1t.q1_time(file_path), number=10)
print(f"Tiempo de ejecución promedio: {execution_time / 10:.5f} segundos")
# Out:
# Tiempo de ejecución promedio: 6.19171 segundos

# %%
# Medir tiempo de ejecución con cProfile
pr = cProfile.Profile()
pr.enable()
q1_time = q1t.q1_time(file_path)
pr.disable()

# Generar reporte
s = StringIO()
ps = pstats.Stats(pr, stream=s).sort_stats(pstats.SortKey.TIME)
ps.print_stats()
print(s.getvalue())
# Out:
#          7985152 function calls (7867314 primitive calls) in 9.375 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    117407    3.988    0.000    3.988    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\json\decoder.py:343(raw_decode)
#    117407    0.645    0.000    0.783    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:182(<dictcomp>)
#         1    0.628    0.628    5.368    5.368 C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\dataset_treatment.py:7(<listcomp>)
#        13    0.483    0.037    0.483    0.037 {pandas._libs.tslibs.vectorized.ints_to_pydatetime}
#    117407    0.384    0.000    0.517    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:184(<dictcomp>)
#     49772    0.346    0.000    0.346    0.000 {built-in method _codecs.charmap_decode}
# 5287077/5287042    0.291    0.000    0.292    0.000 {built-in method builtins.isinstance}
#       121    0.247    0.002    0.283    0.002 {pandas._libs.lib.maybe_convert_objects}
#         2    0.221    0.111    0.221    0.111 {pandas._libs.lib.dicts_to_array}
#         1    0.215    0.215    9.375    9.375 C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\q1_time.py:15(q1_time)
#    117407    0.161    0.000    1.533    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:167(_normalise_json_ordered)
#    117407    0.160    0.000    4.253    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\json\decoder.py:332(decode)
#    234816    0.153    0.000    0.167    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:915(<genexpr>)
#         1    0.122    0.122    0.122    0.122 {pandas._libs.tslibs.strptime.array_strptime}
#        30    0.107    0.004    0.107    0.004 {built-in method numpy.array}
#         1    0.107    0.107    2.220    2.220 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:245(json_normalize)
#         2    0.099    0.049    0.265    0.133 {pandas._libs.lib.fast_unique_multiple_list_gen}
#         5    0.096    0.019    0.152    0.030 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2224(_merge_blocks)
#         1    0.092    0.092    9.066    9.066 C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\dataset_treatment.py:4(dataset_q1)
#    117407    0.089    0.000    4.371    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\json\__init__.py:299(loads)
#        14    0.076    0.005    0.091    0.007 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2194(_stack_arrays)
#    234817    0.075    0.000    0.075    0.000 {method 'match' of 're.Pattern' objects}
#         5    0.055    0.011    0.055    0.011 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\shape_base.py:219(vstack)
#  117408/1    0.054    0.000    1.633    1.633 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:192(_simple_json_normalize)
#        10    0.050    0.005    0.050    0.005 {pandas._libs.ops.scalar_compare}
#    117407    0.046    0.000    0.058    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:126(_normalise_json)
#         2    0.042    0.021    0.289    0.145 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:96(arrays_to_mgr)
#         1    0.040    0.040    1.633    1.633 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:240(<listcomp>)
#         1    0.034    0.034    0.034    0.034 {built-in method pandas._libs.tslib.array_to_datetime}
#         2    0.032    0.016    0.032    0.016 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:922(<listcomp>)
#     49772    0.023    0.000    0.369    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\encodings\cp1252.py:22(decode)
#        10    0.022    0.002    0.022    0.002 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1014(mode)
#    352226    0.021    0.000    0.021    0.000 {method 'items' of 'dict' objects}
#    117410    0.020    0.000    0.020    0.000 {method 'startswith' of 'str' objects}
#    234814    0.019    0.000    0.019    0.000 {method 'end' of 're.Match' objects}
#       204    0.018    0.000    0.018    0.000 {built-in method numpy.empty}
#    234815    0.013    0.000    0.013    0.000 {method 'keys' of 'dict' objects}
#        24    0.012    0.000    0.012    0.000 {pandas._libs.algos.take_2d_axis0_object_object}
#        50    0.011    0.000    0.011    0.000 {method 'copy' of 'numpy.ndarray' objects}
# 118719/118338    0.010    0.000    0.010    0.000 {built-in method builtins.len}
#    117408    0.008    0.000    0.474    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:633(__iter__)
#         1    0.008    0.008    0.588    0.588 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:351(__array__)
#         1    0.006    0.006    0.006    0.006 {method 'factorize' of 'pandas._libs.hashtable.PyObjectHashTable' objects}
#         1    0.004    0.004    0.759    0.759 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:508(_array_strptime_with_fallback)
#         9    0.004    0.000    0.004    0.000 {method 'clear' of 'dict' objects}
#         1    0.003    0.003    0.634    0.634 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:321(_return_parsed_timezone_results)
#         2    0.003    0.002    0.762    0.381 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:793(to_arrays)
#         1    0.003    0.003    0.003    0.003 {pandas._libs.algos.take_2d_axis1_object_object}
#         1    0.002    0.002    0.002    0.002 {method 'unique' of 'pandas._libs.hashtable.PyObjectHashTable' objects}
#        13    0.001    0.000    0.001    0.000 {pandas._libs.lib.infer_dtype}
#        23    0.001    0.000    0.001    0.000 {pandas._libs.algos.take_2d_axis0_int64_int64}
#         1    0.001    0.001    0.001    0.001 {built-in method io.open}
#       121    0.001    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numeric.py:274(full)
#        13    0.001    0.000    0.001    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         2    0.001    0.000    0.001    0.000 {pandas._libs.algos.take_2d_axis1_int64_int64}
#         1    0.001    0.001    0.001    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1246(_iset_single)
#        83    0.001    0.000    0.045    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:519(sanitize_array)
#        98    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         1    0.001    0.001    0.007    0.007 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:685(size)
#        13    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexers\utils.py:239(maybe_convert_indices)
#        26    0.000    0.000    0.042    0.002 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:478(__new__)
#        59    0.000    0.000    0.020    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:121(_take_nd_ndarray)
#         2    0.000    0.000    0.092    0.046 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2137(_form_blocks)
#        26    0.000    0.000    0.003    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:371(__init__)
#        42    0.000    0.000    0.240    0.006 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1028(convert)
#         9    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_int64_int64}
#        63    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6147(__finalize__)
#        37    0.000    0.000    0.013    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3853(__getitem__)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.tslibs.tzconversion.tz_localize_to_utc}
#         1    0.000    0.000    0.001    0.001 {pandas._libs.tslibs.parsing.guess_datetime_format}
#        69    0.000    0.000    0.050    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1147(maybe_infer_to_datetimelike)
#   248/237    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#        59    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:565(_take_preprocess_indexer_and_fill_value)
#       579    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\generic.py:42(_instancecheck)
#       579    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\generic.py:37(_check)
#         1    0.000    0.000    0.760    0.760 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:369(_convert_listlike_datetimes)
#        67    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:274(__init__)
#        51    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:550(maybe_promote)
#        38    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.016    0.003 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:691(_slice_take_blocks_ax0)
#       121    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6206(__setattr__)
#        52    0.000    0.000    0.020    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1041(take_nd)
#         1    0.000    0.000    0.000    0.000 {function TimelikeOps.copy at 0x000002C6D670F2E0}
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:842(_engine)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1768(ravel)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:991(iget)
#        46    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:649(_simple_new)
#   904/901    0.000    0.000    0.018    0.000 {built-in method builtins.getattr}
#        59    0.000    0.000    0.020    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:59(take_nd)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1740(<listcomp>)
#        30    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5300(__contains__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:156(should_cache)
#         8    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:2293(is_unique)
#        14    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_asarray.py:27(require)
#        90    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1949(dtype)
#        13    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:1110(take)
#        16    0.000    0.000    0.020    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:606(reindex_indexer)
#        13    0.000    0.000    0.009    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:3962(take)
#        25    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1825(from_array)
#       170    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#        52    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:265(make_block_same_class)
#        29    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_dtype.py:346(_name_get)
#        73    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7521(ensure_index)
#         6    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#        10    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexers\utils.py:419(check_array_indexer)
#        46    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2346(get_block_type)
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:228(asarray_tuplesafe)
#       253    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:963(__len__)
#        26    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:69(shape)
#        10    0.000    0.000    0.023    0.002 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:2168(mode)
#       186    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\re\__init__.py:272(_compile)
#       180    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\re\__init__.py:173(search)
#        46    0.000    0.000    0.000    0.000 {method 'add_index_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#         2    0.000    0.000    0.240    0.120 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:928(_finalize_columns_and_data)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:618(is_integer_dtype)
#         2    0.000    0.000    0.004    0.002 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:596(_homogenize)
#        10    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:5885(_construct_result)
#        26    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:127(_get_single_key)
#        82    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:695(_sanitize_ndim)
#       142    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:334(is_hashable)
#        26    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4402(_get_item_cache)
#        32    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5350(__getitem__)
#        32    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2317(maybe_coerce_values)
#        10    0.000    0.000    0.008    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3921(_getitem_bool_array)
#         2    0.000    0.000    1.052    0.526 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:665(__init__)
#       115    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\__init__.py:33(using_copy_on_write)
#        13    0.000    0.000    0.009    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:852(take)
#        54    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1425(_is_dtype_type)
#        11    0.000    0.000    0.010    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:639(copy)
#        32    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:562(_get_axis)
#         2    0.000    0.000    0.240    0.120 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1068(<listcomp>)
#       132    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_np_dtype}
#        25    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2388(new_block)
#        59    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#       108    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:420(extract_array)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#        42    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1587(pandas_dtype)
#         7    0.000    0.000    0.000    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#        16    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3776(_ixs)
#        11    0.000    0.000    0.005    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:670(<listcomp>)
#        10    0.000    0.000    0.050    0.005 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:290(comparison_op)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:794(_isnan)
#         7    0.000    0.000    0.010    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:308(apply)
#        62    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:653(name)
#         9    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3859(get_indexer)
#        52    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:647(_get_deprecated_option)
#        10    0.000    0.000    0.050    0.005 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\array_ops.py:115(comp_method_OBJECT_ARRAY)
#         2    0.000    0.000    0.519    0.259 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:891(_list_of_dict_to_arrays)
#        63    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7616(maybe_extract_name)
#         2    0.000    0.000    0.152    0.076 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2207(_consolidate)
#        39    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:2678(check_dict_or_set_indexers)
#        26    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:633(_get_root)
#        77    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:485(ensure_wrapped_if_datetimelike)
#        67    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\flags.py:53(__init__)
#        10    0.000    0.000    0.052    0.005 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:5794(_cmp_method)
#        35    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:703(name)
#        14    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_asarray.py:108(<setcomp>)
#       130    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        29    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:760(_set_axis)
#        19    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:931(from_blocks)
#        54    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#         7    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2375(new_block_2d)
#         8    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#        22    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:765(_try_cast)
#        39    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:335(_from_mgr)
#        24    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1183(is_bool_dtype)
#        12    0.000    0.000    0.009    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4077(_take_with_is_copy)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5153(_get_engine_target)
#        26    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:145(_get_option)
#       172    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.006    0.006 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\algorithms.py:610(factorize)
#         1    0.000    0.000    0.002    0.002 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\algorithms.py:427(unique_with_mask)
#        45    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6189(__getattr__)
#         1    0.000    0.000    0.001    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\methods\selectn.py:90(compute)
#        14    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:198(_consolidate_key)
#        80    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:734(_sanitize_str_dtypes)
#         1    0.000    0.000    0.006    0.006 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\algorithms.py:548(factorize_array)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:77(get_token)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1544(construct_1d_object_array_from_listlike)
#        32    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:137(is_object_dtype)
#         7    0.000    0.000    0.010    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:540(copy)
#       269    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        26    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:271(__call__)
#        59    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:326(_get_take_nd_function)
#       109    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FF87F02C4D0}
#        12    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:96(is_bool_indexer)
#        49    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1960(internal_values)
#        63    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\flags.py:89(allows_duplicate_labels)
#         7    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1734(_consolidate_check)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4384(_box_col_values)
#        15    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\warnings.py:466(__enter__)
#        10    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:2545(check_bool_indexer)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\base.py:836(__iter__)
#        24    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:198(_simple_new)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2467(extend_blocks)
#        38    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1562(validate_all_hashable)
#        90    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:626(dtype)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6961(drop)
#       100    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:909(__len__)
#        51    0.000    0.000    0.000    0.000 {method 'any' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:812(get_grouper)
#        32    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:187(is_extension)
#         2    0.000    0.000    0.035    0.018 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:2159(_sequence_to_dt64ns)
#        50    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\__init__.py:43(using_pyarrow_string_dtype)
#       181    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         1    0.000    0.000    0.007    0.007 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5621(filter)
#        30    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:192(_can_consolidate)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\concat.py:52(concat_compat)
#        20    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1025(needs_i8_conversion)
#        46    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1799(__init__)
#         1    0.000    0.000    0.002    0.002 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\algorithms.py:307(unique)
#         1    0.000    0.000    0.761    0.761 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:721(to_datetime)
#        17    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\missing.py:642(na_value_for_dtype)
#        18    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:641(_constructor_from_mgr)
#        66    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:556(require_length_match)
#        75    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:71(<genexpr>)
#         2    0.000    0.000    0.008    0.004 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:618(get_result)
#         2    0.000    0.000    0.008    0.004 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4719(_drop_axis)
#        70    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:831(_reset_identity)
#        22    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5519(equals)
#        82    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:754(_maybe_repeat)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#        32    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1322(is_ea_or_datetimelike_dtype)
#        17    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3763(get_loc)
#        15    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1066(is_numeric_dtype)
#         2    0.000    0.000    0.035    0.018 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:299(_from_sequence_not_strict)
#        42    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2124(_grouping_func)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#        76    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1581(<genexpr>)
#        95    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:666(_parse)
#        59    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:548(_get_axis_number)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:119(maybe_convert_platform)
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6321(_should_compare)
#        29    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:225(set_axis)
#        29    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:73(_validate_set_axis)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:8727(groupby)
#        22    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:487(_validate_dtype)
#         7    0.000    0.000    0.152    0.022 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1744(_consolidate_inplace)
#        13    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        49    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:750(_values)
#        59    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3548(_intersection_via_get_indexer)
#         1    0.000    0.000    0.018    0.018 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\accessors.py:90(_delegate_property_get)
#        51    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_methods.py:55(_any)
#        40    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:367(apply_if_callable)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:226(fill_value)
#        11    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:865(sort)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:592(_dtype_to_subclass)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:274(_simple_new)
#        13    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\algorithms.py:184(_reconstruct_data)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#       170    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:403(__init__)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:574(_ensure_array)
#        12    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\algorithms.py:106(_ensure_data)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:654(_constructor_sliced_from_mgr)
#        47    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#        62    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         2    0.000    0.000    0.244    0.122 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2068(create_block_manager_from_column_arrays)
#        10    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:134(__new__)
#         7    0.000    0.000    0.000    0.000 {method 'view' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:2209(is_monotonic_increasing)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:478(_get_ndims)
#         2    0.000    0.000    0.008    0.004 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4680(drop)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\algorithms.py:280(_check_object_for_strings)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1025(argsort)
#        26    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\base.py:510(find)
#         7    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3945(_get_indexer)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:206(count_not_none)
#        26    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:615(_select_options)
#        83    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        21    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#        37    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1390(_get_dtype)
#        46    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1255(is_1d_only_ea_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\tools\datetimes.py:216(_maybe_cache)
#        26    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:686(_warn_if_deprecated)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5458(_concat)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:53(_wrapfunc)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:674(_with_infer)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:2378(maybe_convert_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5173(delete)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:901(tz_localize)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:1139(take)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\shape_base.py:81(atleast_2d)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:564(tz)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6134(_raise_if_missing)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:1372(_set_as_cached)
#        10    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1956(external_values)
#        12    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.003    0.003 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:1024(_rename)
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:459(_engine_type)
#        87    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5127(_values)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:568(_get_block_manager_axis)
#        58    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:583(dtype)
#        22    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:791(is_)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:1913(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3428(intersection)
#         2    0.000    0.000    0.035    0.018 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\datetimes.py:318(__new__)
#       121    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\multiarray.py:1080(copyto)
#        10    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:977(is_numeric_v_string_like)
#         1    0.000    0.000    0.001    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\methods\selectn.py:187(compute)
#        10    0.000    0.000    0.052    0.005 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\common.py:62(new_method)
#       128    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:393(flags)
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:773(_view)
#         2    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5987(reset_index)
#         1    0.000    0.000    0.004    0.004 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4257(_set_item_mgr)
#        28    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2212(<lambda>)
#        15    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\warnings.py:440(__init__)
#        29    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_dtype.py:330(_name_includes_bit_suffix)
#        10    0.000    0.000    0.052    0.005 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arraylike.py:38(__eq__)
#         9    0.000    0.000    0.004    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4399(_clear_item_cache)
#         7    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\warnings.py:181(_add_filter)
#        27    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:554(equals)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_string_array}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:875(_parse_numeric_token)
#        48    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#         8    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6251(_maybe_promote)
#        23    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:195(is_array_like)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5563(append)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2233(<listcomp>)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1007(iget)
#         4    0.000    0.000    0.003    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6553(copy)
#        16    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:651(_sliced_from_mgr)
#        15    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\common.py:81(get_op_result_name)
# ...
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\re\__init__.py:163(match)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:319(jump)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:813(_local_timestamps)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:2060(_creso)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:689(_get_result_dim)
#         7    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:335(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:85(consensus_name_attr)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:1991(freq)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4190(_validate_positional_slice)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5392(_getitem_slice)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7580(ensure_has_len)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:916(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\dtypes.py:1789(construct_from_string)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:5434(_reindex_output)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:521(is_string_dtype)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:530(temp_setattr)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:791(isna)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1289(<genexpr>)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\enum.py:1255(value)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:557(condition)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:175(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:756(_shallow_copy)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:692(_constructor)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\api.py:344(<setcomp>)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:915(__array__)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3191(_validate_sort_keyword)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:203(_can_hold_na)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:914(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:482(<dictcomp>)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:2520(_validate_tz_from_dtype)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\base.py:346(shape)
#         7    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1790(ndim)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\methods\selectn.py:202(get_indexer)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:591(_constructor_expanddim)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:638(_passed_categorical)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:1046(_is_label_like)
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.is_utc}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1881(nonzero)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_methods.py:47(_sum)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\api.py:281(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:631(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\ops.py:683(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:949(is_in_axis)
#         1    0.000    0.000    0.000    0.000 {method 'increment_above' of 'pandas._libs.internals.BlockPlacement' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:965(is_in_obj)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\shape_base.py:77(_atleast_2d_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:514(is_string_or_object_np_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:671(<lambda>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexers\utils.py:62(is_list_like_indexer)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:506(f)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:782(_rename)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:708(result_index)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:2069(_obj_1d_constructor)
#         6    0.000    0.000    0.000    0.000 {method 'isspace' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3180(_get_reconciled_name_object)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:1780(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1658(_get_list_axis)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:2665(need_slice)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3544(_wrap_intersection_result)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:228(_constructor)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:621(_can_hold_na)
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool_list}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:1133(_parsems)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\dateutil\tz\_factories.py:13(__call__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1724(np_can_hold_element)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5610(identical)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:766(_maybe_check_integrity)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:720(<listcomp>)
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_int_or_none}
#         3    0.000    0.000    0.000    0.000 {method 'is_finite' of 'decimal.Decimal' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\multiarray.py:892(bincount)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5559(_append_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4311(_validate_can_reindex)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:381(is_unique)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:402(inferred_type)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:360(convertyear)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:402(has_year)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numeric.py:1455(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\base.py:159(_freeze)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimelike.py:2388(validate_inferred_freq)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:661(_ilevel)
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\dateutil\tz\tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numeric.py:2374(_array_equal_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1764(_ravel_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5169(_delete_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:1954(nlevels)
#         1    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\dateutil\parser\_parser.py:186(__iter__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numeric.py:1389(_moveaxis_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1877(_nonzero_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5365(_insert_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\arrays\datetimes.py:2434(_maybe_infer_tz)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\api.py:282(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7678(_maybe_try_sort)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:299(stop)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1945(index)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\base.py:346(_is_boolean)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:292(_consolidate_inplace)
#         1    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x000002C6D68F0720}

# %% [markdown]
# Utilizamos ambas librerias para medir el tiempo de la solucion del top 10 con mas tweets. Utilizando timeit nos da un promedio de tiempo de 6.19 segundos luego de ponderar 10 ejecuciones sobre la misma función. Por otro lado, cProfile nos da un resumen de tiempo sobre cada paso en la ejecucion de funciones de nuestra solución en la cual podemos ver que gran parte del tiempo se consume en la carga y conversion del .json a un df. Asi que nuestra solución en cuestión de tiempo es decente.

# %%
print("El top 10 fechas con mas tweets enfocado a la optimización de tiempo es: \n")
print(q1_time)
# Out:
# El top 10 fechas con mas tweets enfocado a la optimización de tiempo es:
#
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'), (datetime.date(2021, 2, 13), 'MaanDee08215437'), (datetime.date(2021, 2, 17), 'RaaJVinderkaur'), (datetime.date(2021, 2, 16), 'jot__b'), (datetime.date(2021, 2, 14), 'rebelpacifist'), (datetime.date(2021, 2, 18), 'neetuanjle_nitu'), (datetime.date(2021, 2, 15), 'jot__b'), (datetime.date(2021, 2, 20), 'MangalJ23056160'), (datetime.date(2021, 2, 23), 'Surrypuria'), (datetime.date(2021, 2, 19), 'Preetm91')]

# %% [markdown]
# ### MEMORIA

# %% [markdown]
# En el caso de la optimización de memoria utilizamos <em> value_counts </em> en lugar de groupby, minimiza la creación de copias de datos, y utiliza tipos de datos más eficientes para las operaciones.

# %%
q1_memory = q1m.q1_memory(file_path)

print("El top 10 fechas con mas tweets enfocado a la optimización de memoria es: \n")
print(q1_memory)
# Out:
# Filename: C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\q1_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     16    171.6 MiB    171.6 MiB           1   @profile
#     17                                         def q1_memory(file_path: str) -> List[Tuple[datetime.date, str]]:
#     18
#     19                                             # convierte el path a un df con solo las columnas necesarias ['id', 'date', 'username', 'user_id']
#     20   1117.8 MiB    946.2 MiB           1       df = dt.dataset_q1(file_path)
#     21
#     22                                             # Contar tweets por fecha
#     23   1117.9 MiB      0.1 MiB           1       tweet_counts = df['date'].value_counts().nlargest(10)
#     24
#     25                                             # Inicializar una lista para almacenar los resultados
#     26   1117.9 MiB      0.0 MiB           1       results = []
#     27
#     28                                             # Iterar sobre las top 10 fechas para encontrar el usuario más activo cada día
#     29   1119.8 MiB      0.0 MiB          11       for date in tweet_counts.index:
#     30                                                 # Filtrar los tweets de la fecha actual
#     31   1119.8 MiB      1.2 MiB          10           daily_tweets = df[df['date'] == date]
#     32                                                 # Encontrar el usuario más activo
#     33   1119.8 MiB      0.6 MiB          10           top_user = daily_tweets['username'].value_counts().idxmax()
#     34                                                 # Agregar a la lista de resultados
#     35   1119.8 MiB      0.0 MiB          10           results.append((date, top_user))
#     36
#     37   1119.8 MiB      0.0 MiB           1       return results
#
#
# El top 10 fechas con mas tweets enfocado a la optimización de memoria es:
#
# [(datetime.date(2021, 2, 12), 'RanbirS00614606'), (datetime.date(2021, 2, 13), 'MaanDee08215437'), (datetime.date(2021, 2, 17), 'RaaJVinderkaur'), (datetime.date(2021, 2, 16), 'jot__b'), (datetime.date(2021, 2, 14), 'rebelpacifist'), (datetime.date(2021, 2, 18), 'neetuanjle_nitu'), (datetime.date(2021, 2, 15), 'jot__b'), (datetime.date(2021, 2, 20), 'MangalJ23056160'), (datetime.date(2021, 2, 23), 'Surrypuria'), (datetime.date(2021, 2, 19), 'Preetm91')]

# %% [markdown]
# Volvemos a recalcar que el mayor consumo de memoria lo podemos ver en la primera parte, en la carga del .json y construcción del dataFrame mas no en la solución brindada para devolver el top 10 de tweets

# %% [markdown]
# ## Top 10 Emojis

# %% [markdown]
# ### TIEMPO

# %%
# Medir tiempo de ejecución con py-spy
execution_time = timeit.timeit(lambda: q2t.q2_time(file_path), number=10)
print(f"Tiempo de ejecución promedio: {execution_time / 10:.5f} segundos")
# Out:
# Tiempo de ejecución promedio: 4.75675 segundos

# %%
# Medir tiempo de ejecución con cProfile
pr = cProfile.Profile()
pr.enable()
q2_time = q2t.q2_time(file_path)
pr.disable()

# Generar reporte
s = StringIO()
ps = pstats.Stats(pr, stream=s).sort_stats(pstats.SortKey.TIME)
ps.print_stats()
print(s.getvalue())
# Out:
#          1745764 function calls (1745717 primitive calls) in 7.564 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    117407    4.183    0.000    4.183    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\json\decoder.py:343(raw_decode)
#         1    0.813    0.813    5.851    5.851 C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\dataset_treatment.py:38(<listcomp>)
#    117407    0.425    0.000    0.425    0.000 {method 'findall' of 're.Pattern' objects}
#     49772    0.370    0.000    0.370    0.000 {built-in method _codecs.charmap_decode}
#         1    0.276    0.276    7.563    7.563 C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\q2_time.py:31(q2_time)
#    117407    0.177    0.000    4.498    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\json\decoder.py:332(decode)
#         1    0.171    0.171    0.171    0.171 {pandas._libs.lib.dicts_to_array}
#        55    0.156    0.003    0.157    0.003 {pandas._libs.lib.maybe_convert_objects}
#    117408    0.105    0.000    0.114    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:915(<genexpr>)
#    117407    0.104    0.000    4.641    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\json\__init__.py:299(loads)
#    234814    0.103    0.000    0.103    0.000 {method 'match' of 're.Pattern' objects}
#         2    0.090    0.045    0.131    0.065 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2224(_merge_blocks)
#         5    0.083    0.017    0.091    0.018 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2194(_stack_arrays)
#         1    0.078    0.078    0.533    0.533 C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\q2_time.py:36(<listcomp>)
#         1    0.073    0.073    6.751    6.751 C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\dataset_treatment.py:35(dataset_q2)
#         1    0.064    0.064    0.178    0.178 {pandas._libs.lib.fast_unique_multiple_list_gen}
#         1    0.045    0.045    0.045    0.045 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:922(<listcomp>)
#         1    0.041    0.041    0.269    0.269 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:96(arrays_to_mgr)
#         2    0.040    0.020    0.040    0.020 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\shape_base.py:219(vstack)
#    117407    0.030    0.000    0.455    0.000 C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\q2_time.py:19(extract_emojis)
#    117407    0.028    0.000    0.028    0.000 {method 'startswith' of 'str' objects}
#     49772    0.028    0.000    0.397    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\encodings\cp1252.py:22(decode)
#    234814    0.023    0.000    0.023    0.000 {method 'end' of 're.Match' objects}
# 117610/117565    0.014    0.000    0.014    0.000 {built-in method builtins.len}
# 117921/117919    0.011    0.000    0.011    0.000 {built-in method builtins.isinstance}
#    117408    0.009    0.000    0.009    0.000 {method 'keys' of 'dict' objects}
#        65    0.008    0.000    0.008    0.000 {built-in method numpy.empty}
#         1    0.004    0.004    0.551    0.551 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:793(to_arrays)
#         1    0.004    0.004    0.004    0.004 {pandas._libs.algos.take_2d_axis0_object_object}
#         1    0.002    0.002    0.002    0.002 {built-in method _collections._count_elements}
#        55    0.001    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numeric.py:274(full)
#         1    0.000    0.000    0.001    0.001 {built-in method io.open}
#         1    0.000    0.000    0.091    0.091 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2137(_form_blocks)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\heapq.py:523(nlargest)
#        21    0.000    0.000    0.153    0.007 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1028(convert)
#        23    0.000    0.000    0.005    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:519(sanitize_array)
#        32    0.000    0.000    0.011    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1147(maybe_infer_to_datetimelike)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#        58    0.000    0.000    0.000    0.000 {built-in method numpy.asarray}
#         5    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#         7    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2346(get_block_type)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_asarray.py:27(require)
#         2    0.000    0.000    7.685    3.842 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3517(run_code)
#       142    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:274(__init__)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6206(__setattr__)
#         1    0.000    0.000    0.005    0.005 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:596(_homogenize)
#         1    0.000    0.000    0.820    0.820 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:665(__init__)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:478(__new__)
#         1    0.000    0.000    0.153    0.153 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:928(_finalize_columns_and_data)
#        87    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\generic.py:37(_check)
#         2    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:842(_engine)
#         1    0.000    0.000    0.394    0.394 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:891(_list_of_dict_to_arrays)
#         1    0.000    0.000    0.004    0.004 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:691(_slice_take_blocks_ax0)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3853(__getitem__)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_asarray.py:108(<setcomp>)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:2209(is_monotonic_increasing)
#         1    0.000    0.000    0.153    0.153 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1068(<listcomp>)
#        87    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\generic.py:42(_instancecheck)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2375(new_block_2d)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#         1    0.000    0.000    0.131    0.131 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2207(_consolidate)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:2293(is_unique)
#         8    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_dtype.py:346(_name_get)
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1740(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3548(_intersection_via_get_indexer)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:649(_simple_new)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:69(shape)
#         1    0.000    0.000    0.005    0.005 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5621(filter)
#         2    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#        23    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:695(_sanitize_ndim)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\collections\__init__.py:610(most_common)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:991(iget)
#         8    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7521(ensure_index)
#         2    0.000    0.000    0.000    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6147(__finalize__)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:198(_consolidate_key)
#        23    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:734(_sanitize_str_dtypes)
#         1    0.000    0.000    0.004    0.004 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:606(reindex_indexer)
#         3    0.000    0.000    0.004    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:121(_take_nd_ndarray)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3859(get_indexer)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\base.py:836(__iter__)
#         1    0.000    0.000    0.004    0.004 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5574(_reindex_with_indexers)
#         1    0.000    0.000    0.001    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3428(intersection)
#         1    0.000    0.000    0.131    0.131 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1744(_consolidate_inplace)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\codeop.py:120(__call__)
#         1    0.000    0.000    0.005    0.005 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5266(reindex)
#        21    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2124(_grouping_func)
#        29    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_list_like}
#         1    0.000    0.000    0.223    0.223 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2068(create_block_manager_from_column_arrays)
#        17    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        23    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:420(extract_array)
#         1    0.000    0.000    0.004    0.004 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1041(take_nd)
#        18    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\__init__.py:43(using_pyarrow_string_dtype)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1544(construct_1d_object_array_from_listlike)
#         6    0.000    0.000    0.000    0.000 {method 'add_index_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3776(_ixs)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5153(_get_engine_target)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:53(_wrapfunc)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1025(argsort)
#        55    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#        49    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2467(extend_blocks)
#         3    0.000    0.000    0.004    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:59(take_nd)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:119(maybe_convert_platform)
#        22    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:909(__len__)
#         1    0.000    0.000    0.002    0.002 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\collections\__init__.py:587(__init__)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1066(is_numeric_dtype)
#         1    0.000    0.000    0.005    0.005 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5525(_reindex_axes)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5350(__getitem__)
#        24    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:963(__len__)
#        23    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:754(_maybe_repeat)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4402(_get_item_cache)
#         1    0.000    0.000    0.551    0.551 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:506(nested_data_to_arrays)
#        21    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:556(require_length_match)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2317(maybe_coerce_values)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:1139(take)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\contextlib.py:104(__init__)
#        55    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\multiarray.py:1080(copyto)
#         1    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:562(_get_axis)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\api.py:379(default_index)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\traitlets\traitlets.py:689(__get__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:265(make_block_same_class)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3990(_check_indexing_method)
#        17    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3514(_intersection)
#         9    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FF87F02C4D0}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:654(_constructor_sliced_from_mgr)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\common.py:81(get_op_result_name)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6321(_should_compare)
#         1    0.000    0.000    0.002    0.002 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\collections\__init__.py:660(update)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:127(_get_single_key)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\shape_base.py:81(atleast_2d)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:206(count_not_none)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6077(get_indexer_for)
#        10    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2212(<lambda>)
#        21    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1255(is_1d_only_ea_dtype)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3945(_get_indexer)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:485(ensure_wrapped_if_datetimelike)
#         8    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_dtype.py:330(_name_includes_bit_suffix)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:565(_take_preprocess_indexer_and_fill_value)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4384(_box_col_values)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\__init__.py:33(using_copy_on_write)
#         1    0.000    0.000    0.153    0.153 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1006(convert_object_array)
#         2    0.000    0.000    7.684    3.842 {built-in method builtins.exec}
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5519(equals)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\contextlib.py:299(helper)
#         1    0.000    0.000    0.005    0.005 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5122(reindex)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3015(unique)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:198(_simple_new)
#        18    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:550(maybe_promote)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:187(is_extension)
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_int64_int64}
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1425(_is_dtype_type)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\traitlets\traitlets.py:651(get)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5300(__contains__)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1960(internal_values)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\flags.py:53(__init__)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\contextlib.py:141(__exit__)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1322(is_ea_or_datetimelike_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1734(_consolidate_check)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\IPython\core\compilerop.py:180(extra_flags)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:2678(check_dict_or_set_indexers)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:335(_from_mgr)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2233(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\Temp\ipykernel_20100\193300998.py:1(<module>)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numerictypes.py:357(issubdtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:633(_get_root)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\heapq.py:565(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3763(get_loc)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:271(__call__)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:459(_engine_type)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:574(_ensure_array)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:192(_can_consolidate)
#        13    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_np_dtype}
#        23    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5127(_values)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4328(reindex)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:647(_get_deprecated_option)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numerictypes.py:283(issubclass_)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:404(is_dataclass)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1025(needs_i8_conversion)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\contextlib.py:132(__enter__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:145(_get_option)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:2724(inferred_type)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:641(_constructor_from_mgr)
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:71(<genexpr>)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:334(is_hashable)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7616(maybe_extract_name)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:773(_view)
#         2    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:367(apply_if_callable)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:931(from_blocks)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1366(_is_dtype)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:791(is_)
#         7    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:831(_reset_identity)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:196(mgr_to_mgr)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5509(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5560(_needs_reindex_multi)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6251(_maybe_promote)
#         8    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_dtype.py:24(_kind_name)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\common.py:103(_maybe_match_name)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6343(_is_comparable_dtype)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3469(compare)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:865(sort)
#         2    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:950(_validate_or_indexify_columns)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:548(_get_axis_number)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1726(is_consolidated)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7651(_unpack_nested_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:1372(_set_as_cached)
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_scalar}
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:326(_get_take_nd_function)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:226(fill_value)
#        30    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\typing.py:2268(cast)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\shape_base.py:207(_arrays_for_stack_dispatcher)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.all}
#        17    0.000    0.000    0.000    0.000 {built-in method _heapq.heapreplace}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:149(cast_scalar_indexer)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:750(_values)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\flags.py:89(allows_duplicate_labels)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\shape_base.py:215(_vhstack_dispatcher)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1211(take)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:137(is_object_dtype)
#         7    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:210(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\dataclasses.py:1256(is_dataclass)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6239(_index_as_unique)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_methods.py:39(_amax)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1007(iget)
#         9    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3418(_wrap_setop_result)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:169(blknos)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1799(__init__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:532(treat_as_nested)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2268(_preprocess_slice_or_indexer)
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_iterator}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3752(_convert_can_do_setop)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:239(mgr_locs)
#         1    0.000    0.000    0.000    0.000 {method 'copy' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:592(_dtype_to_subclass)
#         1    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2242(<listcomp>)
#        12    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:1657(name)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\missing.py:642(na_value_for_dtype)
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:686(_warn_if_deprecated)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:687(_sanitize_non_ordered)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:651(_sliced_from_mgr)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3544(_wrap_intersection_result)
#         1    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:393(flags)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:583(dtype)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:615(_select_options)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1390(_get_dtype)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:1255(user_global_ns)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:2774(_na_value)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:556(_get_axis_name)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6619(_maybe_cast_listlike_indexer)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:126(_classes_and_not_datetimelike)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:568(_get_block_manager_axis)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:539(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4441(_wrap_reindex_result)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:185(blklocs)
#         1    0.000    0.000    0.000    0.000 {method 'sort' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         1    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1021(_argsort_dispatcher)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1107(<lambda>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\heapq.py:579(<listcomp>)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:131(<lambda>)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:358(attrs)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:2756(_is_multi)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4311(_validate_can_reindex)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:756(_shallow_copy)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:916(<genexpr>)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\multiarray.py:153(concatenate)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\flags.py:57(allows_duplicate_labels)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:974(dtype)
#         1    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:306(is_named_tuple)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:637(_constructor)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:230(is_single_block)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1902(_block)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:896(__init__)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:195(is_array_like)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5610(identical)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:674(_translate_key)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:123(<lambda>)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:121(classes)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\missing.py:971(clean_reindex_fill_method)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3191(_validate_sort_keyword)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3746(_assert_can_do_setop)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7580(ensure_has_len)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:692(_constructor)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6612(_maybe_cast_indexer)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:1169(_maybe_disallow_fill)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\shape_base.py:77(_atleast_2d_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\base.py:363(ndim)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7678(_maybe_try_sort)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:861(_sort_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4445(_maybe_preserve_names)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}

# %% [markdown]
# La optimización de este codigo se da de 3 maneras:
# 1) La expresión regular emoji_pattern se compila una vez fuera de la función extract_emojis, lo que evita la recompilación en cada llamada, mejorando así la eficiencia.
# 2) se utiliza una list comprehension para extraer emojis directamente y concatenarlos en una sola lista. Esto evita la sobrecarga de aplicar funciones a nivel de DataFrame y facilita la creación de una lista plana de emojis.
# 3) 'Counter' se aplica directamente a la lista de emojis extraídos, evitando conversiones adicionales o estructuras intermedias.
#
# Por otro lado, al igual que el anterior ejercicio en lo que mas tiempo se gasta es en la carga y conversion de .json al DataFrame.
# Con el metodo py-spy se demora en promedio 6.5 segundos
# Con el metodo Cprofile se demora 18.4 segundos

# %%
df2 = q2t.q2_time(file_path)
print("El top 10 emojis con su conteo enfocado a la optimización de tiempo es: \n")
df2
# Out:
# El top 10 fechas con mas tweets enfocado a la optimización de tiempo es:
# [('🙏', 1916),
#  ('❤️', 952),
#  ('😂', 627),
#  ('🌾', 529),
#  ('💚', 493),
#  ('👍', 459),
#  ('👉', 450),
#  ('✊', 437),
#  ('🇮🇳', 399),
#  ('👇', 387)]

# %% [markdown]
# ### MEMORIA

# %%
q2_memory = q2m.q2_memory(file_path)

print("El top 10 emojis con su conteo enfocado a la optimización de memoria es: \n")
print(q2_memory)
# Out:
# Filename: C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\q2_memory.py
#
# Line #    Mem usage    Increment  Occurrences   Line Contents
# =============================================================
#     26    120.6 MiB    120.6 MiB           1   @profile
#     27                                         def q2_memory(file_path: str) -> List[Tuple[str, int]]:
#     28                                             # convierte el path a un df con solo las columnas necesarias ['content']
#     29   1171.9 MiB   1051.4 MiB           1       df = dt.dataset_q2(file_path)
#     30
#     31                                             # Generador para emojis extraídos
#     32   1171.9 MiB      0.0 MiB      160326       emoji_gen = (emoji for text in df['content'] for emoji in extract_emojis(text))
#     33
#     34                                             # Contar emojis directamente desde el generador
#     35   1171.9 MiB      0.0 MiB           1       emoji_counts = Counter(emoji_gen)
#     36
#     37                                             # Obtener el top 10 de emojis más usados
#     38   1171.9 MiB      0.0 MiB           1       top_10_emojis = emoji_counts.most_common(10)
#     39   1171.9 MiB      0.0 MiB           1       return top_10_emojis
#
#
# El top 10 emojis con su conteo enfocado a la optimización de memoria es:
#
# [('🙏', 1916), ('❤️', 952), ('😂', 627), ('🌾', 529), ('💚', 493), ('👍', 459), ('👉', 450), ('✊', 437), ('🇮🇳', 399), ('👇', 387)]

# %% [markdown]
# La optimización de este codigo se da de 3 maneras:
# 1) Evitar la creación de listas intermedias grandes y usar generadores cuando sea posible.
# 2) Utilizar itertools.chain para crear iteradores en lugar de listas.
# 3) Utilizar collections.Counter eficientemente para acumular conteos en lugar de almacenar todos los emojis y luego contarlos.
#
# Nuevamente el mayor consumo de memoria lo podemos ver en la primera parte, en la carga del .json y construcción del dataFrame mas no en la solución brindada para devolver el top 10 de emojis con sus conteos

# %% [markdown]
# ##  Top 10 histórico de usuarios mencionando

# %% [markdown]
# ### TIEMPO

# %%
# Medir tiempo de ejecución con py-spy
execution_time = timeit.timeit(lambda: q3t.q3_time(file_path), number=10)
print(f"Tiempo de ejecución promedio: {execution_time / 10:.5f} segundos")
# Out:
# Tiempo de ejecución promedio: 9.31101 segundos

# %%
# Medir tiempo de ejecución con cProfile
pr = cProfile.Profile()
pr.enable()
q3_time = q3t.q3_time(file_path)
pr.disable()

# Generar reporte
s = StringIO()
ps = pstats.Stats(pr, stream=s).sort_stats(pstats.SortKey.TIME)
ps.print_stats()
print(s.getvalue())
# Out:
#          26965419 function calls (26378241 primitive calls) in 23.189 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    117407    5.547    0.000    5.547    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\json\decoder.py:343(raw_decode)
#         1    1.237    1.237    8.089    8.089 C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\dataset_treatment.py:57(<listcomp>)
# 9843903/9843897    0.968    0.000    1.288    0.000 {built-in method builtins.isinstance}
#    117522    0.891    0.000    1.313    0.000 {pandas._libs.lib.maybe_convert_objects}
#    117407    0.852    0.000    1.047    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:182(<dictcomp>)
#    117408    0.851    0.000    7.207    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:371(__init__)
#         1    0.589    0.589   23.189   23.189 C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\q3_time.py:16(q3_time)
#    117461    0.568    0.000    2.442    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:519(sanitize_array)
#    117407    0.502    0.000    0.695    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:184(<dictcomp>)
#     49772    0.441    0.000    0.441    0.000 {built-in method _codecs.charmap_decode}
#         2    0.393    0.196    0.393    0.196 {pandas._libs.lib.dicts_to_array}
#    117407    0.392    0.000    6.158    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\json\decoder.py:332(decode)
#    193475    0.378    0.000    1.657    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:1016(__getitem__)
#    117407    0.345    0.000    2.187    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:167(_normalise_json_ordered)
#    117418    0.335    0.000    0.477    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6147(__finalize__)
# 1799729/1329964    0.309    0.000    0.442    0.000 {built-in method builtins.len}
#    117523    0.265    0.000    0.421    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numeric.py:274(full)
#    117473    0.262    0.000    1.186    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1147(maybe_infer_to_datetimelike)
#    117408    0.252    0.000    7.977    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:1401(iterrows)
#    193475    0.251    0.000    0.893    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:1139(_get_value)
#    117408    0.250    0.000    0.963    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1825(from_array)
#    117418    0.221    0.000    0.274    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:274(__init__)
#    234816    0.206    0.000    0.222    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:915(<genexpr>)
#    193480    0.199    0.000    0.227    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1960(internal_values)
#    117410    0.197    0.000    0.474    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:127(_get_single_key)
#    117418    0.190    0.000    0.881    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6206(__setattr__)
#    193478    0.170    0.000    0.310    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3763(get_loc)
#    117408    0.166    0.000    0.296    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2388(new_block)
#    234814    0.165    0.000    0.165    0.000 {method 'match' of 're.Pattern' objects}
#    117408    0.162    0.000    0.282    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:653(name)
#    117414    0.156    0.000    0.279    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2317(maybe_coerce_values)
#    193478    0.151    0.000    0.222    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:2678(check_dict_or_set_indexers)
#    117409    0.147    0.000    0.518    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:760(_set_axis)
#    117407    0.145    0.000    6.367    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\json\__init__.py:299(loads)
#         5    0.142    0.028    0.214    0.043 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2224(_merge_blocks)
#    425234    0.140    0.000    0.320    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\generic.py:42(_instancecheck)
#    425234    0.137    0.000    0.179    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\generic.py:37(_check)
#    469697    0.133    0.000    0.174    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:909(__len__)
#    117408    0.131    0.000    0.409    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:703(name)
#    117410    0.129    0.000    0.167    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:633(_get_root)
#    234820    0.129    0.000    0.129    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:647(_get_deprecated_option)
#    117408    0.126    0.000    0.428    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\missing.py:184(_isna)
#    117408    0.121    0.000    0.121    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6189(__getattr__)
#    193478    0.119    0.000    0.119    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#         1    0.117    0.117    3.146    3.146 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:245(json_normalize)
#         2    0.116    0.058    0.338    0.169 {pandas._libs.lib.fast_unique_multiple_list_gen}
#    117410    0.111    0.000    0.751    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:145(_get_option)
#         1    0.107    0.107   12.387   12.387 C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\dataset_treatment.py:54(dataset_q3)
#        14    0.103    0.007    0.121    0.009 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2194(_stack_arrays)
#    117461    0.097    0.000    0.182    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:695(_sanitize_ndim)
#    117428    0.096    0.000    0.129    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2346(get_block_type)
#    310892    0.090    0.000    0.090    0.000 {pandas._libs.lib.is_scalar}
#    117409    0.087    0.000    0.242    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:73(_validate_set_axis)
#    117567    0.085    0.000    0.085    0.000 {built-in method numpy.empty}
#    117409    0.084    0.000    0.278    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1562(validate_all_hashable)
#    117407    0.082    0.000    0.568    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\missing.py:380(notna)
#    193480    0.081    0.000    0.308    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:750(_values)
#    234838    0.076    0.000    0.096    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7521(ensure_index)
#    660190    0.076    0.000    0.076    0.000 {built-in method builtins.getattr}
#  117408/1    0.076    0.000    2.330    2.330 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:192(_simple_json_normalize)
#    234831    0.076    0.000    0.114    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:334(is_hashable)
#    117425    0.073    0.000    0.082    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:485(ensure_wrapped_if_datetimelike)
#         5    0.071    0.014    0.071    0.014 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\shape_base.py:219(vstack)
#    117410    0.071    0.000    0.823    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:271(__call__)
#    117560    0.070    0.000    0.070    0.000 {built-in method numpy.asarray}
#    234818    0.069    0.000    0.126    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1581(<genexpr>)
#    117418    0.068    0.000    0.194    0.000 {built-in method builtins.all}
#    117409    0.067    0.000    0.308    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:225(set_axis)
#         2    0.061    0.030    0.061    0.030 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:922(<listcomp>)
#    117461    0.060    0.000    0.072    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:420(extract_array)
#    193479    0.060    0.000    0.082    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:367(apply_if_callable)
#    117407    0.059    0.000    0.076    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:126(_normalise_json)
#    117418    0.059    0.000    0.059    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\flags.py:89(allows_duplicate_labels)
#         1    0.059    0.059    2.330    2.330 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\io\json\_normalize.py:240(<listcomp>)
#    117450    0.057    0.000    0.156    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:556(require_length_match)
#         2    0.055    0.028    0.401    0.201 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:96(arrays_to_mgr)
#     38034    0.055    0.000    0.055    0.000 C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\dataset_treatment.py:51(<dictcomp>)
#    117461    0.054    0.000    0.067    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:734(_sanitize_str_dtypes)
#    117418    0.053    0.000    0.053    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\flags.py:53(__init__)
#    117419    0.051    0.000    0.108    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7616(maybe_extract_name)
#    386954    0.050    0.000    0.050    0.000 {pandas._libs.lib.is_integer}
#    117461    0.049    0.000    0.063    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\construction.py:754(_maybe_repeat)
#    117408    0.049    0.000    0.477    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\missing.py:101(isna)
#    117407    0.048    0.000    0.048    0.000 {method 'startswith' of 'str' objects}
#    117410    0.047    0.000    0.131    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:686(_warn_if_deprecated)
#     49772    0.044    0.000    0.485    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\encodings\cp1252.py:22(decode)
#    117410    0.042    0.000    0.042    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1799(__init__)
#    117410    0.040    0.000    0.086    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:674(_translate_key)
#    117438    0.040    0.000    0.040    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\__init__.py:33(using_copy_on_write)
#    234834    0.038    0.000    0.038    0.000 {built-in method builtins.hash}
#    117410    0.037    0.000    0.037    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\config.py:615(_select_options)
#    117410    0.037    0.000    0.037    0.000 {method 'split' of 'str' objects}
#    352227    0.034    0.000    0.034    0.000 {method 'items' of 'dict' objects}
#    234814    0.034    0.000    0.034    0.000 {method 'end' of 're.Match' objects}
#    234837    0.032    0.000    0.032    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:393(flags)
#    234886    0.031    0.000    0.031    0.000 {pandas._libs.lib.is_list_like}
#    117410    0.028    0.000    0.028    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1902(_block)
#    117408    0.025    0.000    0.025    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:464(__iter__)
#    234956    0.024    0.000    0.024    0.000 {built-in method builtins.issubclass}
#     79382    0.024    0.000    0.024    0.000 {built-in method pandas._libs.missing.checknull}
#    117523    0.023    0.000    0.023    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\multiarray.py:1080(copyto)
#    193478    0.022    0.000    0.022    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6612(_maybe_cast_indexer)
#    193486    0.022    0.000    0.022    0.000 {built-in method builtins.callable}
#         1    0.021    0.021    0.091    0.091 {pandas._libs.lib.map_infer}
#    117419    0.019    0.000    0.019    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:358(attrs)
#    117419    0.019    0.000    0.019    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\flags.py:57(allows_duplicate_labels)
#    234816    0.016    0.000    0.016    0.000 {method 'keys' of 'dict' objects}
#    117407    0.015    0.000    0.069    0.000 C:\Users\JuanLH.MYMIRATECH\Documents\Workspace git\latam-challange\src\dataset_treatment.py:48(list_to_dict)
#    117408    0.013    0.000    0.013    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:1381(_clear_item_cache)
#    117484    0.011    0.000    0.011    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\typing.py:2268(cast)
#         3    0.010    0.003    0.010    0.003 {pandas._libs.algos.take_2d_axis0_object_object}
#        10    0.010    0.001    0.010    0.001 {method 'copy' of 'numpy.ndarray' objects}
#         1    0.009    0.009    0.017    0.017 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1669(_interleave)
#         4    0.008    0.002    0.008    0.002 {pandas._libs.algos.take_2d_axis1_object_object}
#         5    0.007    0.001    0.007    0.001 {method 'astype' of 'numpy.ndarray' objects}
#     38088    0.005    0.000    0.005    0.000 {built-in method builtins.hasattr}
#         2    0.004    0.002    1.212    0.606 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:793(to_arrays)
#         1    0.001    0.001    0.001    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\heapq.py:523(nlargest)
#         4    0.001    0.000    0.001    0.000 {pandas._libs.algos.take_2d_axis1_int64_int64}
#         2    0.001    0.000    0.001    0.000 {pandas._libs.algos.take_2d_axis0_int64_int64}
#        42    0.001    0.000    0.415    0.010 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1028(convert)
#         2    0.001    0.000    0.122    0.061 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2137(_form_blocks)
#         1    0.000    0.000    0.000    0.000 {built-in method io.open}
#         1    0.000    0.000    0.017    0.017 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1596(as_array)
#         4    0.000    0.000    0.025    0.006 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:691(_slice_take_blocks_ax0)
#         1    0.000    0.000    0.000    0.000 {function Counter.update at 0x000001C6856542C0}
#        11    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:478(__new__)
#        13    0.000    0.000    0.000    0.000 {pandas._libs.lib.infer_dtype}
#        21    0.000    0.000    0.023    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:121(_take_nd_ndarray)
#        18    0.000    0.000    0.000    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        14    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_asarray.py:27(require)
#         2    0.000    0.000    0.009    0.004 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:596(_homogenize)
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:842(_engine)
#        16    0.000    0.000    0.000    0.000 {built-in method numpy.array}
#        21    0.000    0.000    0.024    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:59(take_nd)
#         2    0.000    0.000    0.415    0.208 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1068(<listcomp>)
#         5    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#         3    0.000    0.000    0.005    0.002 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3853(__getitem__)
#         8    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:2293(is_unique)
#        13    0.000    0.000    0.024    0.002 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1041(take_nd)
#         9    0.000    0.000    0.000    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2375(new_block_2d)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         2    0.000    0.000    0.415    0.208 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:928(_finalize_columns_and_data)
#         2    0.000    0.000    1.613    0.806 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:665(__init__)
#         2    0.000    0.000    0.792    0.396 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:891(_list_of_dict_to_arrays)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1740(<listcomp>)
#         9    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3859(get_indexer)
#        27    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_dtype.py:346(_name_get)
#        22    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:649(_simple_new)
#        14    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_asarray.py:108(<setcomp>)
#         2    0.000    0.000    0.214    0.107 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2207(_consolidate)
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:228(asarray_tuplesafe)
#        13    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:265(make_block_same_class)
#        11    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2467(extend_blocks)
#         1    0.000    0.000    0.008    0.008 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5574(_reindex_with_indexers)
#        58    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#        13    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:69(shape)
#         2    0.000    0.000    0.337    0.168 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2068(create_block_manager_from_column_arrays)
#         1    0.000    0.000    0.009    0.009 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5621(filter)
#         5    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#         4    0.000    0.000    0.025    0.006 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:606(reindex_indexer)
#        18    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5153(_get_engine_target)
#         6    0.000    0.000    0.009    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:639(copy)
#        21    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:565(_take_preprocess_indexer_and_fill_value)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\base.py:836(__iter__)
#        22    0.000    0.000    0.000    0.000 {method 'add_index_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#         2    0.000    0.000    0.014    0.007 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4680(drop)
#        42    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2124(_grouping_func)
#        14    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:198(_consolidate_key)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3548(_intersection_via_get_indexer)
#         3    0.000    0.000    0.009    0.003 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:308(apply)
#         1    0.000    0.000    0.091    0.091 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\apply.py:1264(apply_standard)
#         2    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6961(drop)
#        50    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\_config\__init__.py:43(using_pyarrow_string_dtype)
#        33    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:192(_can_consolidate)
#         7    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:931(from_blocks)
#        66    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:963(__len__)
#         2    0.000    0.000    0.014    0.007 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4719(_drop_axis)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:2209(is_monotonic_increasing)
#         8    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_int64_int64}
#         5    0.000    0.000    0.215    0.043 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1744(_consolidate_inplace)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1544(construct_1d_object_array_from_listlike)
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#        10    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1066(is_numeric_dtype)
#        10    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6321(_should_compare)
#        79    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_np_dtype}
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6251(_maybe_promote)
#        10    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:562(_get_axis)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:119(maybe_convert_platform)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:1139(take)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:991(iget)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6896(insert)
#         8    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:550(maybe_promote)
#        21    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\array_algos\take.py:326(_get_take_nd_function)
#        14    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5519(equals)
#        13    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\missing.py:642(na_value_for_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5369(insert)
#        33    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:187(is_extension)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3945(_get_indexer)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5560(_needs_reindex_multi)
#        13    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:226(fill_value)
#       146    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\warnings.py:466(__enter__)
#        58    0.000    0.000    0.000    0.000 <frozen abc>:117(__instancecheck__)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5300(__contains__)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5173(delete)
#         3    0.000    0.000    0.009    0.003 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:540(copy)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:53(_wrapfunc)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1025(argsort)
#         1    0.000    0.000    0.001    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3428(intersection)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1734(_consolidate_check)
#         1    0.000    0.000    0.001    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6101(_get_indexer_strict)
#         1    0.000    0.000    0.007    0.007 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:618(get_result)
#         5    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6077(get_indexer_for)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:641(_constructor_from_mgr)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6134(_raise_if_missing)
#        28    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2212(<lambda>)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:3776(_ixs)
#        43    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1255(is_1d_only_ea_dtype)
#        22    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1322(is_ea_or_datetimelike_dtype)
#        28    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:831(_reset_identity)
#         4    0.000    0.000    0.007    0.002 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2245(get_values)
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:459(_engine_type)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4384(_box_col_values)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4402(_get_item_cache)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1311(insert)
#        36    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x00007FF87F02C4D0}
#         1    0.000    0.000    0.008    0.008 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5266(reindex)
#         2    0.000    0.000    1.212    0.606 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:506(nested_data_to_arrays)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\codeop.py:120(__call__)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6856(delete)
#         1    0.000    0.000    0.003    0.003 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:1024(_rename)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:206(count_not_none)
#        11    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:574(_ensure_array)
#        13    0.000    0.000    0.000    0.000 {method 'max' of 'numpy.ndarray' objects}
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\shape_base.py:81(atleast_2d)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\concat.py:52(concat_compat)
#        14    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:791(is_)
#        13    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:2724(inferred_type)
#        27    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_dtype.py:330(_name_includes_bit_suffix)
#        19    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1425(_is_dtype_type)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1400(find_common_type)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\ops\common.py:81(get_op_result_name)
#         1    0.000    0.000    0.007    0.007 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:157(concat)
#         8    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:335(_from_mgr)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4257(_set_item_mgr)
#         1    0.000    0.000    0.008    0.008 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:5525(_reindex_axes)
#        13    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_methods.py:39(_amax)
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1025(needs_i8_conversion)
#        39    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:71(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:403(__init__)
#         1    0.000    0.000    0.004    0.004 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:3962(take)
#        10    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:1366(_is_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexers\utils.py:239(maybe_convert_indices)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5350(__getitem__)
#         2    0.000    0.000   23.281   11.641 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3517(run_code)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2233(<listcomp>)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#        83    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5127(_values)
#        41    0.000    0.000    0.000    0.000 {pandas._libs.algos.ensure_platform_int}
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3990(_check_indexing_method)
#         1    0.000    0.000    0.001    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\collections\__init__.py:610(most_common)
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\warnings.py:440(__init__)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:198(_simple_new)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4328(reindex)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1758(concat_horizontal)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1683(<listcomp>)
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:568(_get_block_manager_axis)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#        10    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7651(_unpack_nested_dtype)
#         1    0.000    0.000    0.001    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4062(__setitem__)
#        11    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:592(_dtype_to_subclass)
#         1    0.000    0.000    0.003    0.003 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5399(rename)
#        20    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:548(_get_axis_number)
#         1    0.000    0.000    0.004    0.004 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4077(_take_with_is_copy)
#         2    0.000    0.000    0.014    0.007 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5196(drop)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numeric.py:1393(moveaxis)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:654(_constructor_sliced_from_mgr)
#        14    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5563(append)
#        18    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6239(_index_as_unique)
#        10    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6343(_is_comparable_dtype)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:297(slice_block_columns)
#         1    0.000    0.000    0.008    0.008 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5122(reindex)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5272(_validate_fill_value)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3514(_intersection)
#         1    0.000    0.000    0.003    0.003 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6553(copy)
#         4    0.000    0.000    0.000    0.000 {method 'take' of 'numpy.ndarray' objects}
#        22    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:239(mgr_locs)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:773(_view)
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:137(is_object_dtype)
#        27    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_dtype.py:24(_kind_name)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:674(_with_infer)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numerictypes.py:357(issubdtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:96(is_bool_indexer)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:865(sort)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\api.py:202(union_indexes)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:404(is_dataclass)
#        38    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:583(dtype)
#         1    0.000    0.000    0.001    0.001 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4290(_set_item)
#         1    0.000    0.000    0.017    0.017 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:12207(values)
#         2    0.000    0.000    0.415    0.208 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1006(convert_object_array)
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\warnings.py:487(__exit__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\api.py:120(_get_combined_index)
#         9    0.000    0.000    0.001    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6619(_maybe_cast_listlike_indexer)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:566(copy_func)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:2268(_preprocess_slice_or_indexer)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1359(np_find_common_type)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1211(take)
#         8    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numerictypes.py:283(issubclass_)
#         1    0.000    0.000    0.004    0.004 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:852(take)
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1726(is_consolidated)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.any}
#         2    0.000    0.000   23.281   11.641 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numeric.py:1330(normalize_axis_tuple)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\api.py:379(default_index)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5458(_concat)
#         1    0.000    0.000    0.091    0.091 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\algorithms.py:1738(map_array)
#         1    0.000    0.000    0.091    0.091 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\apply.py:1191(apply)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\collections\__init__.py:660(update)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:196(mgr_to_mgr)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\contextlib.py:104(__init__)
# ...
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:366(ensure_np_dtype)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:651(_sliced_from_mgr)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:556(_get_axis_name)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numeric.py:1380(<listcomp>)
#         7    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:210(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:747(_set_axis_nocheck)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:2483(ensure_block_shape)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\base.py:61(__len__)
#         9    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\common.py:123(<lambda>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:703(_get_comb_axis)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:565(<listcomp>)
#         5    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:920(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:543(_get_sample_object)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\apply.py:111(__init__)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6182(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6465(<listcomp>)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:300(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:500(get_rename_function)
#        10    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\missing.py:971(clean_reindex_fill_method)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1007(iget)
#         1    0.000    0.000    0.000    0.000 {method 'sum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\missing.py:696(is_valid_na_for_dtype)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4314(_set_is_copy)
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#         3    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\api.py:323(_sanitize_and_check)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:235(items)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1430(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3544(_wrap_intersection_result)
#        13    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\multiarray.py:153(concatenate)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:1751(_get_names)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5453(<setcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:747(<listcomp>)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\inference.py:306(is_named_tuple)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:626(dtype)
#         3    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1439(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:756(_shallow_copy)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:916(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {method 'add' of 'pandas._libs.internals.BlockPlacement' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\heapq.py:579(<listcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\api.py:102(<listcomp>)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:692(_constructor)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3746(_assert_can_do_setop)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1003(shape)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:821(__len__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\_methods.py:47(_sum)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:638(_info_axis)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7580(ensure_has_len)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:1255(user_global_ns)
#         4    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:949(axes)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3191(_validate_sort_keyword)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:1169(_maybe_disallow_fill)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4337(_check_setitem_copy)
#         1    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1724(np_can_hold_element)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4361(_ensure_valid_index)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:4311(_validate_can_reindex)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5462(<listcomp>)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1446(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:171(not_none)
#         6    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\base.py:363(ndim)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:6177(<genexpr>)
#         2    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         4    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\concat.py:73(<listcomp>)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:506(f)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:1539(__len__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3180(_get_reconciled_name_object)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:782(_rename)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\common.py:175(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5610(identical)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\api.py:281(<listcomp>)
#         3    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#         5    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\shape_base.py:77(_atleast_2d_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\dtypes\cast.py:1441(<genexpr>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\api.py:344(<setcomp>)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:689(_get_result_dim)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\series.py:577(_constructor)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\compat\numpy\function.py:64(__call__)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4453(_check_inplace_and_allows_duplicate_labels)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7678(_maybe_try_sort)
#         3    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:335(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool_list}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numeric.py:1455(<listcomp>)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:377(dtype)
#         1    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:861(_sort_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\fromnumeric.py:1764(_ravel_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5169(_delete_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5365(_insert_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:1954(nlevels)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\multiarray.py:892(bincount)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\multiarray.py:669(result_type)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\core\numeric.py:1389(_moveaxis_dispatcher)
#         2    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\numpy\lib\function_base.py:5559(_append_dispatcher)
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\concat.py:766(_maybe_check_integrity)
#         1    0.000    0.000    0.000    0.000 {function FrozenList.__getitem__ at 0x000001C68BED0720}
#         1    0.000    0.000    0.000    0.000 C:\Users\JuanLH.MYMIRATECH\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\api.py:282(<listcomp>)

# %%
print("El top 10 histórico de usuarios (username) más influyentes en función del conteo de las menciones enfocado a la optimización de tiempo es: \n")
q3_time
# Out:
# El top 10 histórico de usuarios (username) más influyentes en función del conteo de las menciones enfocado a la optimización de tiempo es:
# [('loyal90901246', 2450),
#  ('_gurviir', 1807),
#  ('neetuanjle_nitu', 1728),
#  ('JaiHind58236291', 1695),
#  ('preetysaini321', 926),
#  ('JoyJ69957841', 911),
#  ('Gurpreetd86', 839),
#  ('jot__b', 830),
#  ('mani262002', 777),
#  ('ScitaramSays', 762)]

# %% [markdown]
# La optimización de tiempo sobre este codigo se da de la siguiente forma:
#
# 1) Se Utiliza defaultdict para contar de manera eficiente y Counter para una rápida identificación de los elementos más comunes.
# 2) Se procesa solo las filas relevantes evitando operaciones innecesarias.
# 3) Se utiliza iterrows para iterar sobre las filas, que es una buena opción cuando la operación por fila es lo suficientemente compleja para amortiguar la sobrecarga de iteración.
