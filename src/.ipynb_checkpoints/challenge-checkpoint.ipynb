# %% [markdown]
# ## Librerias Usadas

# %%
import json
import pandas as pd

# %% [markdown]
# ## Carga del Archivo

# %% [markdown]
# En este archivo puedes escribir lo que estimes conveniente. Te recomendamos detallar tu solución y todas las suposiciones que estás considerando. Aquí puedes ejecutar las funciones que definiste en los otros archivos de la carpeta src, medir el tiempo, memoria, etc.

# %%
file_path = "farmers-protest-tweets-2021-2-4.json"

# %%
# Lee el archivo JSON línea por línea y carga cada línea como un objeto JSON
with open(file_path, 'r') as file:
    data = [json.loads(line) for line in file]

# Convierte los datos en un DataFrame
df = pd.DataFrame(data)

# %% [markdown]
# ## Analisis Exploratorio

# %% [markdown]
# Durante esta sección haremos un pequeño analisis exploratorio sobre el DataFrame <em> farmers-protest-tweets-2021-2-4.json </em> para conocer un poco sobre el comportamiento de los datos

# %%
# Muestra de la primera fila de DF
df.head(1)
# Out:
#                                                  url  \
# 0  https://twitter.com/ArjunSinghPanam/status/136...
#
#                         date  \
# 0  2021-02-24T09:23:35+00:00
#
#                                              content  \
# 0  The world progresses while the Indian police a...
#
#                                      renderedContent                   id  \
# 0  The world progresses while the Indian police a...  1364506249291784198
#
#                                                 user  \
# 0  {'username': 'ArjunSinghPanam', 'displayname':...
#
#                                             outlinks  \
# 0  [https://twitter.com/ravisinghka/status/136415...
#
#                  tcooutlinks  replyCount  retweetCount  ...  quoteCount  \
# 0  [https://t.co/es3kn0IQAF]           0             0  ...           0
#
#         conversationId  lang  \
# 0  1364506249291784198    en
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
#
#                             sourceUrl         sourceLabel media  \
# 0  http://twitter.com/download/iphone  Twitter for iPhone  None
#
#   retweetedTweet                                        quotedTweet  \
# 0           None  {'url': 'https://twitter.com/RaviSinghKA/statu...
#
#                                       mentionedUsers
# 0  [{'username': 'narendramodi', 'displayname': '...
#
# [1 rows x 21 columns]

# %% [markdown]
# Haremos un recorte de nuestro DataFrame dado que solo necesitamos algunos de los atributos del DF para realizar nuestro challenge:
# 1) Date, user, id
# 2) content
# 3) user, mentionedUsers

# %%
df= df.filter(items=['id','date','content','user','mentionedUsers'])
df.head()
# Out:
#                     id                       date  \
# 0  1364506249291784198  2021-02-24T09:23:35+00:00
# 1  1364506237451313155  2021-02-24T09:23:32+00:00
# 2  1364506195453767680  2021-02-24T09:23:22+00:00
# 3  1364506167226032128  2021-02-24T09:23:16+00:00
# 4  1364506144002088963  2021-02-24T09:23:10+00:00
#
#                                              content  \
# 0  The world progresses while the Indian police a...
# 1  #FarmersProtest \n#ModiIgnoringFarmersDeaths \...
# 2  ਪੈਟਰੋਲ ਦੀਆਂ ਕੀਮਤਾਂ ਨੂੰ ਮੱਦੇਨਜ਼ਰ ਰੱਖਦੇ ਹੋਏ \nਮੇ...
# 3  @ReallySwara @rohini_sgh watch full video here...
# 4  #KisanEktaMorcha #FarmersProtest #NoFarmersNoF...
#
#                                                 user  \
# 0  {'username': 'ArjunSinghPanam', 'displayname':...
# 1  {'username': 'PrdeepNain', 'displayname': 'Pra...
# 2  {'username': 'parmarmaninder', 'displayname': ...
# 3  {'username': 'anmoldhaliwal', 'displayname': '...
# 4  {'username': 'KotiaPreet', 'displayname': 'Pre...
#
#                                       mentionedUsers
# 0  [{'username': 'narendramodi', 'displayname': '...
# 1  [{'username': 'Kisanektamorcha', 'displayname'...
# 2                                               None
# 3  [{'username': 'ReallySwara', 'displayname': 'S...
# 4                                               None

# %% [markdown]
# Vamos a convertir los atributos al tipo de datos que sea mejor para el tratamiento de los mismos

# %%
# Convertir la columna 'id' a int64
df['id'] = df['id'].astype(int)

# Convertir la columna 'date' a DateTime
df['date'] = pd.to_datetime(df['date'])

# %%
def resumen_columnas(df):
    print("Información del DataFrame:\n")
    print(df.info())
    print("\nDescripción Estadística:\n")
    print(df.describe(include='all'))
    print("\nTipos de Datos:\n")
    print(df.dtypes)
    print("\nConteo de Valores Nulos:\n")
    print(df.isnull().sum())

# Aplicar la función
resumen_columnas(df)
# Out:
# Información del DataFrame:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117407 entries, 0 to 117406
# Data columns (total 21 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   url              117407 non-null  object
#  1   date             117407 non-null  object
#  2   content          117407 non-null  object
#  3   renderedContent  117407 non-null  object
#  4   id               117407 non-null  int64
#  5   user             117407 non-null  object
#  6   outlinks         117407 non-null  object
#  7   tcooutlinks      117407 non-null  object
#  8   replyCount       117407 non-null  int64
#  9   retweetCount     117407 non-null  int64
#  10  likeCount        117407 non-null  int64
#  11  quoteCount       117407 non-null  int64
#  12  conversationId   117407 non-null  int64
#  13  lang             117407 non-null  object
#  14  source           117407 non-null  object
#  15  sourceUrl        116495 non-null  object
#  16  sourceLabel      116495 non-null  object
#  17  media            28109 non-null   object
#  18  retweetedTweet   0 non-null       object
#  19  quotedTweet      41436 non-null   object
#  20  mentionedUsers   38034 non-null   object
# dtypes: int64(6), object(15)
# memory usage: 18.8+ MB
# None
#
# Descripción Estadística:
#
#                                                       url  \
# count                                              117407
# unique                                             117407
# top     https://twitter.com/ArjunSinghPanam/status/136...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                              date          content  renderedContent  \
# count                      117407           117407           117407
# unique                     109652           112453           106652
# top     2021-02-20T12:57:17+00:00  #FarmersProtest  #FarmersProtest
# freq                            7             1560             1560
# mean                          NaN              NaN              NaN
# std                           NaN              NaN              NaN
# min                           NaN              NaN              NaN
# 25%                           NaN              NaN              NaN
# 50%                           NaN              NaN              NaN
# 75%                           NaN              NaN              NaN
# max                           NaN              NaN              NaN
#
#                   id                                               user  \
# count   1.174070e+05                                             117407
# unique           NaN                                              29579
# top              NaN  {'username': 'jot__b', 'displayname': 'Jot', '...
# freq             NaN                                               1019
# mean    1.362062e+18                                                NaN
# std     1.293803e+15                                                NaN
# min     1.360040e+18                                                NaN
# 25%     1.360935e+18                                                NaN
# 50%     1.361945e+18                                                NaN
# 75%     1.363097e+18                                                NaN
# max     1.364506e+18                                                NaN
#
#        outlinks tcooutlinks     replyCount   retweetCount  ...     quoteCount  \
# count    117407      117407  117407.000000  117407.000000  ...  117407.000000
# unique    28731       49456            NaN            NaN  ...            NaN
# top          []          []            NaN            NaN  ...            NaN
# freq      66944       66944            NaN            NaN  ...            NaN
# mean        NaN         NaN       0.631410       5.045619  ...       0.336241
# std         NaN         NaN       9.436159      58.237370  ...       4.474576
# min         NaN         NaN       0.000000       0.000000  ...       0.000000
# 25%         NaN         NaN       0.000000       0.000000  ...       0.000000
# 50%         NaN         NaN       0.000000       0.000000  ...       0.000000
# 75%         NaN         NaN       0.000000       1.000000  ...       0.000000
# max         NaN         NaN    1291.000000    7723.000000  ...     756.000000
#
#         conversationId    lang  \
# count     1.174070e+05  117407
# unique             NaN      46
# top                NaN      en
# freq               NaN   48429
# mean      1.361764e+18     NaN
# std       1.294352e+16     NaN
# min       1.981606e+10     NaN
# 25%       1.360887e+18     NaN
# 50%       1.361914e+18     NaN
# 75%       1.363068e+18     NaN
# max       1.364506e+18     NaN
#
#                                                    source  \
# count                                              117407
# unique                                                 82
# top     <a href="http://twitter.com/download/android" ...
# freq                                                58962
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                   sourceUrl          sourceLabel  \
# count                                116495               116495
# unique                                   80                   81
# top     http://twitter.com/download/android  Twitter for Android
# freq                                  58962                58962
# mean                                    NaN                  NaN
# std                                     NaN                  NaN
# min                                     NaN                  NaN
# 25%                                     NaN                  NaN
# 50%                                     NaN                  NaN
# 75%                                     NaN                  NaN
# max                                     NaN                  NaN
#
#                                                     media retweetedTweet  \
# count                                               28109              0
# unique                                              26598              0
# top     [{'previewUrl': 'https://pbs.twimg.com/media/E...            NaN
# freq                                                   50            NaN
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#                                               quotedTweet  \
# count                                               41436
# unique                                              22354
# top     {'url': 'https://twitter.com/sikh_coalition/st...
# freq                                                  144
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                            mentionedUsers
# count                                               38034
# unique                                              17980
# top     [{'username': 'narendramodi', 'displayname': '...
# freq                                                  680
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
# [11 rows x 21 columns]
#
# Tipos de Datos:
#
# url                object
# date               object
# content            object
# renderedContent    object
# id                  int64
# user               object
# outlinks           object
# tcooutlinks        object
# replyCount          int64
# retweetCount        int64
# likeCount           int64
# quoteCount          int64
# conversationId      int64
# lang               object
# source             object
# sourceUrl          object
# sourceLabel        object
# media              object
# retweetedTweet     object
# quotedTweet        object
# mentionedUsers     object
# dtype: object
#
# Conteo de Valores Nulos:
#
# url                     0
# date                    0
# content                 0
# renderedContent         0
# id                      0
# user                    0
# outlinks                0
# tcooutlinks             0
# replyCount              0
# retweetCount            0
# likeCount               0
# quoteCount              0
# conversationId          0
# lang                    0
# source                  0
# sourceUrl             912
# sourceLabel           912
# media               89298
# retweetedTweet     117407
# quotedTweet         75971
# mentionedUsers      79373
# dtype: int64
